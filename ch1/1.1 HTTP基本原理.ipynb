# %% [markdown]
# # 1.1 HTTP基本原理

# %% [markdown]
# ## 1.URI和URL

# %% [markdown]
# URI的全称为Uniform Resource Identifier，即统一资源标志符；
#
# URL的全称为Universal Resourse Locator，即统一资源定位符；
#
# 举例：https://github.com/favicon.ico 既是一个URI也是一个URL
#
# 通过一个链接，便可以从互联网中找到某个资源，这个链接就是URI/URL
#
# URL是URI的子集
#
# URL遵循一定的格式

# %% [markdown]
# ## 2.HTTP和HTTPS

# %% [markdown]
# 这是两个常见的协议

# %% [markdown]
# HTTP的全称是Hypertext Transfer Protocal，中文名为超文本传输协议，其作用是把超文本数据从网络传输到本地浏览器，能够保证高效而准确地传输超文本文档

# %% [markdown]
# 目前广泛使用的是HTTP1.1版本，现在也有不少网站支持HTTP2.0
#
# HTTPS全称是Hypertext Transfer Protocal over Secure Socket Layer
#
# 简单来说就是HTTP的安全版，即在HTTP下加入SSL层，简称HTTPS

# %% [markdown]
# HTTPS的安全基础是SSL，因此通过该协议传输的内容都是经过SSL加密的

# %% [markdown]
# SSL的主要作用：
#
# * 建立一个信息安全通道，保证数据传输的安全性
# * 确认网站的真实性

# %% [markdown]
# HTTPS已经是大势所趋

# %% [markdown]
# ## 3.HTTP请求过程

# %% [markdown]
# 1. 浏览器先向网站所在的服务器发送一个请求
# 2. 网站服务器接收到请求后对其进行处理和解析
# 3. 然后返回对应的响应，接着传回浏览器
# 4. 浏览器再对其进行解析，便将网页呈现出来

# %% [markdown]
# ## 4.请求

# %% [markdown]
# 请求，英文为Request，由客户端发往服务器，分为四部分内容：请求方法（Request Method）、请求的网址（Request URL）、请求头（Request Headers）、请求体（Request Body）

# %% [markdown]
# * **请求方法**

# %% [markdown]
# 常见的两种：GET 和 POST

# %% [markdown]
# <font color=Blue>**在浏览器中输入URL并回车，便发起了一个GET请求，请求的参数会直接包含在URL里**</font>

# %% [markdown]
# <font color=Blue>**POST请求大多在提交表单时发起**</font>

# %% [markdown]
# 例如：对于一个登录表单，输入用户名和密码后，单机“登录”按钮，这时通常会发起一个POST请求，其数据通常以表单的形式传输，而不会体现在URL中

# %% [markdown]
# GET和POST的区别：
#
# * GET请求中的参数包含在URL里面，数据可以在URL中看到；而POST请求的URL不会包含这些数据，数据都是通过表单形式传输的，会包含在请求体中。
#
# * GET请求提交的数据最多只有1024字节，POST方式则没有限制。

# %% [markdown]
# * **请求的网址**

# %% [markdown]
# 请求的网址，它可以唯一确定客户端想请求的资源

# %% [markdown]
# * **请求头**

# %% [markdown]
# 请求头，用来说明服务器要使用的附加信息，比较重要的信息有Cookie、Referer、User-Agent等

# %% [markdown]
# 简要说明一些常用请求头信息：
#
# * Cookie：也常用复数形式Cookies，这是网站为了辨别用户，进行会话跟踪而存储在用户本地的数据。它的功能主要是维持当前访问会话。例如：用户输入账号密码登录某个网站后，服务器会用会话保存登录状态信息。每次浏览器在请求登录该站点的页面时，都会在请求头中加上Cookie并将其发送给服务器，服务器通过Cookie识别出是我们自己，并且查出当前状态是登录状态，所以返回结果就是登录之后才能看到的页面内容。
#
# * Referer：用于标识请求是从哪个页面发过来的
#
# * User-Agent：简称UA，可以使服务器识别客户端使用的操作系统及版本、浏览器及版本等信息。**做爬虫时加上这些可以伪装浏览器！**

# %% [markdown]
# 请求头是请求的重要组成部分，在写爬虫时，通常都需要设定请求头

# %% [markdown]
# * **请求体**

# %% [markdown]
# 请求体，一般承载的内容是POST请求中的表单数据，对于GET请求，请求体为空

# %% [markdown]
# 注意此时Request Headers中的Content-Type为application/x-www-form-urlencoded

# %% [markdown]
# 只有这样设置，内容才会以表单数据的形式提交

# %% [markdown]
# 在爬虫中，构造POST请求需要使用正确的Content-Type

# %% [markdown]
# ## 5.响应

# %% [markdown]
# * **响应状态码**

# %% [markdown]
# 200代表服务器正常响应

# %% [markdown]
# 404代表页面未找到

# %% [markdown]
# * **响应头**

# %% [markdown]
# 响应头，包含了服务器对请求的应答信息

# %% [markdown]
# * **响应体**

# %% [markdown]
# 最关键的部分，响应的正文部分都存在于响应体中，例如请求网页时，响应体就是网页的HTML代码；请求一张图片时，响应体就是图片的二进制数据。我们做爬虫请求网页时，要解析的内容就是响应体

# %% [markdown]
# ## 6.HTTP2.0

# %% [markdown]
# * **二进制分帧层**

# %% [markdown]
# * **多路复用**

# %% [markdown]
# * **流控制**

# %% [markdown]
# * **服务端推送**

# %% [markdown]
# * **HTTP2.0发展现状**

# %% [markdown]
# ## 7.总结
